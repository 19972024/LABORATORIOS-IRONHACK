# %% [markdown]
# # PANDAS LAB - Continuation of the EuroLeague Case Study
# ## Let's compare the competitions!
#
# ![](https://eurospects.com/wp-content/uploads/2018/10/eurocupeuroleague.png)
#
# First of all, we must
#
# - Import the actual.csv Dataset. This dataset will be the CSV of the result obtained in class.
# - Import ec23.xlsx. This dataset correspond to the import the dataset corresponding to Eurocup. Don't worry, this time the Excel will be cleaned (almost)
#
# <details>
#     <summary> Lab results </summary>
#
# ![](https://media1.tenor.com/m/lx2WSGRk8bcAAAAC/pulp-fiction-john-travolta.gif)
#
# PERO QUÉ OS HABÉIS CREÍDO
#
# </details>

# %%
# !pip install openpyxl
# In case there is an error with this .xlsx document opening, install this library
# Out:
# Requirement already satisfied: openpyxl in c:\users\matte\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in c:\users\matte\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
import pandas as pd
import numpy as np

# %%
league=pd.read_csv("C:/Users/matte/Documents/CSV/actual.csv")
cup=pd.read_excel("C:/Users/matte/Documents/XLS/ec2023.xlsx", index_col=False)

# %% [markdown]
# Let's analyze the EuroCup Dataframe! Is there any cleaning needed? Remember the basics:
# - Drop Null Values
# - Drop Duplicate Rows
# - Drop Strange Columns if you see any

# %%
# Your Code here: 
league.sample(10)
# Out:
#     Competition           Phase  Ronda         Dia      Hora  \
# 177  Euroleague  Regular Season     20  2024-01-09  20:30:00
# 103  Euroleague  Regular Season     12  2023-12-05  20:30:00
# 96   Euroleague  Regular Season     11  2023-12-01  20:00:00
# 214  Euroleague  Regular Season     24  2024-01-31  20:15:00
# 220  Euroleague  Regular Season     25  2024-02-02  18:30:00
# 150  Euroleague  Regular Season     17  2023-12-28  20:30:00
# 162  Euroleague  Regular Season     19  2024-01-04  18:45:00
# 72   Euroleague  Regular Season      9  2023-11-16  20:05:00
# 34   Euroleague  Regular Season      4  2023-10-20  20:30:00
# 32   Euroleague  Regular Season      4  2023-10-20  19:30:00
#
#                                   Local                           Visitante  \
# 177             LDLC ASVEL Villeurbanne  Crvena Zvezda Meridianbet Belgrade
# 103                    FC Bayern Munich            EA7 Emporio Armani Milan
# 96   Crvena Zvezda Meridianbet Belgrade               Anadolu Efes Istanbul
# 214          Panathinaikos AKTOR Athens            EA7 Emporio Armani Milan
# 220               Anadolu Efes Istanbul            EA7 Emporio Armani Milan
# 150            EA7 Emporio Armani Milan            Baskonia Vitoria-Gasteiz
# 162            Fenerbahce Beko Istanbul           Maccabi Playtika Tel Aviv
# 72            Maccabi Playtika Tel Aviv            Fenerbahce Beko Istanbul
# 34             Virtus Segafredo Bologna  Crvena Zvezda Meridianbet Belgrade
# 32                Anadolu Efes Istanbul                     Valencia Basket
#
#      Localscore  Roadscore                                           Arbitros  \
# 177         100         91  ['JAVOR, DAMIR', 'PATERNICO, CARMELO', 'RACYS,...
# 103          91         84  ['PUKL,SASA', 'OBRKNEZEVIC, UROS ', 'PETEK, SA...
# 96           97         83  ['PATERNICO, CARMELO', 'CORTES, CARLOS', 'BAEN...
# 214          79         62  ['JAVOR, DAMIR', 'VILIUS, GYTIS', 'KONSTANTINO...
# 220          79         73  ['PEREZ, MIGUEL ANGEL', 'KARDUM, LUKA', 'BAENA...
# 150          76         67  ['DIFALLAH, MEHDI', 'VILIUS, GYTIS', 'RADOJKOV...
# 162         109         74  ['LOTTERMOSER, ROBERT', 'VILIUS, GYTIS', 'KOWA...
# 72           78         73  ['BELOSEVIC, ILIJA', 'BISSANG, JOSEPH', 'OBRKN...
# 34           85         79  ['PERUGA, CARLOS', 'DRAGOJEVIC, IGOR', 'THEPEN...
# 32           77         73  ['ROCHA, FERNANDO', 'LATISEVS, OLEGS', 'BISSUE...
#
#      Plusminus                              Winner Ganador
# 177          9             LDLC ASVEL Villeurbanne   Local
# 103          7                    FC Bayern Munich   Local
# 96          14  Crvena Zvezda Meridianbet Belgrade   Local
# 214         17          Panathinaikos AKTOR Athens   Local
# 220          6               Anadolu Efes Istanbul   Local
# 150          9            EA7 Emporio Armani Milan   Local
# 162         35            Fenerbahce Beko Istanbul   Local
# 72           5           Maccabi Playtika Tel Aviv   Local
# 34           6            Virtus Segafredo Bologna   Local
# 32           4               Anadolu Efes Istanbul   Local

# %%
cup.sample(10)
# Out:
#      Unnamed: 0                fecha  ronda                        local  \
# 140         138  2023-10-24T20:00:00      4           Umana Reyer Venice
# 111         109  2023-11-14T18:00:00      7   7bet-Lietkabelis Panevezys
# 158         155  2023-10-11T18:30:00      2  Cedevita Olimpija Ljubljana
# 115         113  2023-11-08T20:00:00      6                Slask Wroclaw
# 63           63  2023-12-13T19:45:00     11     Buducnost VOLI Podgorica
# 171         168  2023-10-03T19:30:00      1               ratiopharm Ulm
# 141         139  2023-10-24T19:30:00      4        Veolia Towers Hamburg
# 41           41  2023-12-27T20:00:00     13      Dolomiti Energia Trento
# 91           90  2023-11-28T18:00:00      9               Wolves Vilnius
# 93           92  2023-11-22T19:00:00      8      Aris Midea Thessaloniki
#
#                       visitante  localscore  roadscore     Winner  Ganador  \
# 140           Joventut Badalona          79       64.0      Local     79.0
# 111         Turk Telekom Ankara          93       86.0      Local     93.0
# 158           Joventut Badalona          87       88.0  Visitante     88.0
# 115     Dolomiti Energia Trento          75       84.0  Visitante     84.0
# 63          Turk Telekom Ankara          73       96.0  Visitante     96.0
# 171     Dolomiti Energia Trento          80       70.0      Local     80.0
# 141      Hapoel Shlomo Tel Aviv          72      111.0  Visitante    111.0
# 41   7bet-Lietkabelis Panevezys          76       70.0      Local     76.0
# 91                 London Lions          87      101.0  Visitante    101.0
# 93               ratiopharm Ulm          88       99.0  Visitante     99.0
#
#      plusminus
# 140       15.0
# 111        7.0
# 158       -1.0
# 115       -9.0
# 63       -23.0
# 171       10.0
# 141      -39.0
# 41         6.0
# 91       -14.0
# 93       -11.0

# %%
league.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Competition  225 non-null    object
#  1   Phase        225 non-null    object
#  2   Ronda        225 non-null    int64
#  3   Dia          225 non-null    object
#  4   Hora         225 non-null    object
#  5   Local        225 non-null    object
#  6   Visitante    225 non-null    object
#  7   Localscore   225 non-null    int64
#  8   Roadscore    225 non-null    int64
#  9   Arbitros     225 non-null    object
#  10  Plusminus    225 non-null    int64
#  11  Winner       225 non-null    object
#  12  Ganador      225 non-null    object
# dtypes: int64(4), object(9)
# memory usage: 23.0+ KB

# %%
cup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  173 non-null    int64
#  1   fecha       173 non-null    object
#  2   ronda       173 non-null    int64
#  3   local       173 non-null    object
#  4   visitante   173 non-null    object
#  5   localscore  173 non-null    int64
#  6   roadscore   172 non-null    float64
#  7   Winner      173 non-null    object
#  8   Ganador     172 non-null    float64
#  9   plusminus   172 non-null    float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 13.6+ KB

# %%
nulos_por_columna = league.isnull().sum()
print(nulos_por_columna)
# Out:
# Competition    0
# Phase          0
# Ronda          0
# Dia            0
# Hora           0
# Local          0
# Visitante      0
# Localscore     0
# Roadscore      0
# Arbitros       0
# Plusminus      0
# Winner         0
# Ganador        0
# dtype: int64

# %%
nulos_por_columna = cup.isnull().sum()
print(nulos_por_columna)
# Out:
# Unnamed: 0    0
# fecha         0
# ronda         0
# local         0
# visitante     0
# localscore    0
# roadscore     1
# Winner        0
# Ganador       1
# plusminus     1
# dtype: int64

# %%
cup = cup.dropna()

league = league.drop_duplicates()
cup = cup.drop_duplicates()

# %%
nulos_por_columna = cup.isnull().sum()
print(nulos_por_columna)
# Out:
# Unnamed: 0    0
# fecha         0
# ronda         0
# local         0
# visitante     0
# localscore    0
# roadscore     0
# Winner        0
# Ganador       0
# plusminus     0
# dtype: int64

# %% [markdown]
# Let's now compare it with the EL dataset that we have: You might select a sample of both of them and see what are the inconsistencies!

# %%
#Your sample ecteams code here: 
league.sample(12)
# Out:
#     Competition           Phase  Ronda         Dia      Hora  \
# 223  Euroleague  Regular Season     25  2024-02-02  20:30:00
# 62   Euroleague  Regular Season      7  2023-11-10  21:00:00
# 10   Euroleague  Regular Season      2  2023-10-12  20:00:00
# 47   Euroleague  Regular Season      6  2023-11-02  19:00:00
# 50   Euroleague  Regular Season      6  2023-11-03  20:30:00
# 144  Euroleague  Regular Season     17  2023-12-28  18:30:00
# 196  Euroleague  Regular Season     22  2024-01-19  20:15:00
# 97   Euroleague  Regular Season     11  2023-12-01  20:30:00
# 199  Euroleague  Regular Season     23  2024-01-25  20:00:00
# 176  Euroleague  Regular Season     20  2024-01-09  20:30:00
# 44   Euroleague  Regular Season      5  2023-10-27  20:30:00
# 115  Euroleague  Regular Season     13  2023-12-08  20:30:00
#
#                              Local                           Visitante  \
# 223       Virtus Segafredo Bologna       Partizan Mozzart Bet Belgrade
# 62                       AS Monaco             LDLC ASVEL Villeurbanne
# 10         LDLC ASVEL Villeurbanne       Partizan Mozzart Bet Belgrade
# 47                 Zalgiris Kaunas             LDLC ASVEL Villeurbanne
# 50        Virtus Segafredo Bologna               Anadolu Efes Istanbul
# 144  Partizan Mozzart Bet Belgrade            Virtus Segafredo Bologna
# 196     Panathinaikos AKTOR Athens       Partizan Mozzart Bet Belgrade
# 97                 Valencia Basket            Baskonia Vitoria-Gasteiz
# 199                    ALBA Berlin  Crvena Zvezda Meridianbet Belgrade
# 176                Valencia Basket                     Zalgiris Kaunas
# 44                FC Bayern Munich            Fenerbahce Beko Istanbul
# 115                   FC Barcelona            Fenerbahce Beko Istanbul
#
#      Localscore  Roadscore                                           Arbitros  \
# 223          88         84  ['LOTTERMOSER, ROBERT', 'PUKL,SASA', 'TRAWICKI...
# 62           80         70  ['MOGULKOC, EMIN', 'CICI, GENTIAN', 'GIOVANNET...
# 10           62         88  ['LOTTERMOSER, ROBERT', 'MOGULKOC, EMIN', 'RAD...
# 47           88         91  ['PATERNICO, CARMELO', 'SHEMMESH, SEFFI', 'CLI...
# 50           93         81  ['PEREZ, MIGUEL ANGEL', 'RACYS, SAULIUS', 'POR...
# 144          75         77  ['MOGULKOC, EMIN', 'SUKYS, ARTURAS', 'UDYANSKY...
# 196          84         71  ['GARCIA, JUAN CARLOS', 'MOGULKOC, EMIN', 'BOU...
# 97           84         98  ['BOLTAUZER, MATEJ', 'DIFALLAH, MEHDI', 'CICI,...
# 199          89         80  ['PERUGA, CARLOS', 'ROSSI, MICHELE', 'POROBIC,...
# 176          79         84  ['MOGULKOC, EMIN', 'FOUFIS, IOANNIS', 'KARDUM,...
# 44           67         76  ['LATISEVS, OLEGS', 'ALIAGA, JORDI', 'VAN DEN ...
# 115          89         81  ['JAVOR, DAMIR', 'JOVCIC, MILIVOJE', 'SUKYS, A...
#
#      Plusminus                         Winner    Ganador
# 223          4       Virtus Segafredo Bologna      Local
# 62          10                      AS Monaco      Local
# 10         -26  Partizan Mozzart Bet Belgrade  Visitante
# 47          -3        LDLC ASVEL Villeurbanne  Visitante
# 50          12       Virtus Segafredo Bologna      Local
# 144         -2       Virtus Segafredo Bologna  Visitante
# 196         13     Panathinaikos AKTOR Athens      Local
# 97         -14       Baskonia Vitoria-Gasteiz  Visitante
# 199          9                    ALBA Berlin      Local
# 176         -5                Zalgiris Kaunas  Visitante
# 44          -9       Fenerbahce Beko Istanbul  Visitante
# 115          8                   FC Barcelona      Local

# %%
#Your sample elteams code here: 
cup.sample(12)
# Out:
#      Unnamed: 0                fecha  ronda                       local  \
# 128         126  2023-11-01T18:00:00      5  Besiktas Emlakjet Istanbul
# 147         144  2023-10-18T19:00:00      3     Aris Midea Thessaloniki
# 95           94  2023-11-22T18:00:00      8               Slask Wroclaw
# 29           29  2024-01-16T20:00:00     15     Dolomiti Energia Trento
# 100          98  2023-11-21T19:30:00      8       Veolia Towers Hamburg
# 143         140  2023-10-24T18:00:00      4              Wolves Vilnius
# 66           66  2023-12-12T20:30:00     11            Paris Basketball
# 130         128  2023-10-31T20:30:00      5           Joventut Badalona
# 71           71  2023-12-06T21:00:00     10      Dreamland Gran Canaria
# 96           95  2023-11-22T18:00:00      8       Prometey Slobozhanske
# 75           75  2023-12-06T18:00:00     10  Besiktas Emlakjet Istanbul
# 138         136  2023-10-25T18:00:00      4  7bet-Lietkabelis Panevezys
#
#                       visitante  localscore  roadscore     Winner  Ganador  \
# 128          Umana Reyer Venice          74       68.0      Local     74.0
# 147         Turk Telekom Ankara          68       66.0      Local     68.0
# 95   7bet-Lietkabelis Panevezys          71       75.0  Visitante     75.0
# 29                Slask Wroclaw          85       79.0      Local     85.0
# 100              Wolves Vilnius          71       84.0  Visitante     84.0
# 143  Besiktas Emlakjet Istanbul          90       88.0      Local     90.0
# 66           Umana Reyer Venice         100       70.0      Local    100.0
# 130       Veolia Towers Hamburg         108       76.0      Local    108.0
# 71      Aris Midea Thessaloniki          93       65.0      Local     93.0
# 96           Umana Reyer Venice          89       82.0      Local     89.0
# 75            Joventut Badalona          81       85.0  Visitante     85.0
# 138     Dolomiti Energia Trento          92       93.0  Visitante     93.0
#
#      plusminus
# 128        6.0
# 147        2.0
# 95        -4.0
# 29         6.0
# 100      -13.0
# 143        2.0
# 66        30.0
# 130       32.0
# 71        28.0
# 96         7.0
# 75        -4.0
# 138       -1.0

# %% [raw]
# What are the inconsistencies that you are seeing? Write them down!
#
# - # En el df de la Euroliga veo un dataset mas ordenado, mas limpio con alguna columna capas que nos sobra como por ejemplo la columna ganador, y no termino de entender la columna plusminus para que sirve.
# - # En el df de la Eurocup veo un dataset mucho mas sucio y desordenado, unas cuantas columnas para eliminar como Unnamed:0 separar la columna de fecha y hora y la columna roadscore esta como float y no como la columna local que esta en int.
# - # No solo eso la columna winner no da el nomnre del equipo ganador sino el nombre solo si fue equipo local o visitante
#
# <details>
#     <summary> Expand the box to see the inconsistencies </summary>
#
# - The columns are named in lowercase and the columns in Euroleague are capitalized
# - There are some missing columns (f.e. Arbitros)
# - Fecha is not split in Dia and Hora
# - `Winner and Ganador Columns show different data` are not the same! Be extremely careful about it
#
# </details>

# %% [markdown]
# As you can see there are a lot of different inconsistencies right?
# But beofore starting cleaning like crazy people, let's take a second to know what do we want to compare:
#
# - The CLUBS are impossible to compare, as different competitions defines different clubs
# - Both rounds (Eurocup has less rounds) and Dates (Different Dates) are also not really useful
# - We don't have information about Arbitros
#
# ## Conclusion
#
# ### We must take into consideration what data we DO have in both dataframes to compare it propperly and don't use time cleaning unnecessary things.
#
# In this particular case, we will need to compare:

# %% [markdown]
# `Competition`: The main column that define one from another.
#
# Create the Competition column in the EuroCup dataframe, being the fixed value "Eurocup"

# %%
#Your Code here:
cup['Competition'] = 'Eurocup'
cup
# Out:
#      Unnamed: 0                fecha  ronda                        local  \
# 0             0  2024-01-31T21:00:00     17       Dreamland Gran Canaria
# 1             1  2024-01-31T20:00:00     17      Dolomiti Energia Trento
# 2             2  2024-01-31T19:30:00     17               ratiopharm Ulm
# 3             3  2024-01-31T18:30:00     17  Cedevita Olimpija Ljubljana
# 4             4  2024-01-31T18:00:00     17          Turk Telekom Ankara
# ..          ...                  ...    ...                          ...
# 168         165  2023-10-04T18:00:00      1             U-BT Cluj-Napoca
# 169         166  2023-10-04T18:00:00      1        Prometey Slobozhanske
# 170         167  2023-10-03T20:30:00      1             Paris Basketball
# 171         168  2023-10-03T19:30:00      1               ratiopharm Ulm
# 172         169  2023-10-03T19:00:00      1       Hapoel Shlomo Tel Aviv
#
#                           visitante  localscore  roadscore     Winner  \
# 0                  U-BT Cluj-Napoca         111      113.0  Visitante
# 1          Buducnost VOLI Podgorica          78       97.0  Visitante
# 2           Aris Midea Thessaloniki          66       86.0  Visitante
# 3                      London Lions          85       92.0  Visitante
# 4    Mincidelice JL Bourg en Bresse          64       68.0  Visitante
# ..                              ...         ...        ...        ...
# 168             Turk Telekom Ankara          80       71.0      Local
# 169           Veolia Towers Hamburg          97       77.0      Local
# 170                  Wolves Vilnius         105       78.0      Local
# 171         Dolomiti Energia Trento          80       70.0      Local
# 172     Cedevita Olimpija Ljubljana         100       73.0      Local
#
#      Ganador  plusminus Competition
# 0      113.0       -2.0     Eurocup
# 1       97.0      -19.0     Eurocup
# 2       86.0      -20.0     Eurocup
# 3       92.0       -7.0     Eurocup
# 4       68.0       -4.0     Eurocup
# ..       ...        ...         ...
# 168     80.0        9.0     Eurocup
# 169     97.0       20.0     Eurocup
# 170    105.0       27.0     Eurocup
# 171     80.0       10.0     Eurocup
# 172    100.0       27.0     Eurocup
#
# [170 rows x 11 columns]

# %% [markdown]
# `Ganador`: Being the actual values "Local" or "Visitante"
#
# **BE CAREFUL**: Before changing the correct column to "Ganador" from the EC dataframe, there is a "Ganador" column with the incorrect information: STEP BY STEP!

# %%
#Drop the Column Ganador from the Eurocup Dataframe
cup.drop(columns=['Ganador'], inplace=True)
cup
# Out:
#      Unnamed: 0                fecha  ronda                        local  \
# 0             0  2024-01-31T21:00:00     17       Dreamland Gran Canaria
# 1             1  2024-01-31T20:00:00     17      Dolomiti Energia Trento
# 2             2  2024-01-31T19:30:00     17               ratiopharm Ulm
# 3             3  2024-01-31T18:30:00     17  Cedevita Olimpija Ljubljana
# 4             4  2024-01-31T18:00:00     17          Turk Telekom Ankara
# ..          ...                  ...    ...                          ...
# 168         165  2023-10-04T18:00:00      1             U-BT Cluj-Napoca
# 169         166  2023-10-04T18:00:00      1        Prometey Slobozhanske
# 170         167  2023-10-03T20:30:00      1             Paris Basketball
# 171         168  2023-10-03T19:30:00      1               ratiopharm Ulm
# 172         169  2023-10-03T19:00:00      1       Hapoel Shlomo Tel Aviv
#
#                           visitante  localscore  roadscore     Winner  \
# 0                  U-BT Cluj-Napoca         111      113.0  Visitante
# 1          Buducnost VOLI Podgorica          78       97.0  Visitante
# 2           Aris Midea Thessaloniki          66       86.0  Visitante
# 3                      London Lions          85       92.0  Visitante
# 4    Mincidelice JL Bourg en Bresse          64       68.0  Visitante
# ..                              ...         ...        ...        ...
# 168             Turk Telekom Ankara          80       71.0      Local
# 169           Veolia Towers Hamburg          97       77.0      Local
# 170                  Wolves Vilnius         105       78.0      Local
# 171         Dolomiti Energia Trento          80       70.0      Local
# 172     Cedevita Olimpija Ljubljana         100       73.0      Local
#
#      plusminus Competition
# 0         -2.0     Eurocup
# 1        -19.0     Eurocup
# 2        -20.0     Eurocup
# 3         -7.0     Eurocup
# 4         -4.0     Eurocup
# ..         ...         ...
# 168        9.0     Eurocup
# 169       20.0     Eurocup
# 170       27.0     Eurocup
# 171       10.0     Eurocup
# 172       27.0     Eurocup
#
# [170 rows x 10 columns]

# %%
#Rename the column with the actual information to "Ganador"
cup.rename(columns={'Winner': 'Ganador'}, inplace=True)
cup
# Out:
#      Unnamed: 0                fecha  ronda                        local  \
# 0             0  2024-01-31T21:00:00     17       Dreamland Gran Canaria
# 1             1  2024-01-31T20:00:00     17      Dolomiti Energia Trento
# 2             2  2024-01-31T19:30:00     17               ratiopharm Ulm
# 3             3  2024-01-31T18:30:00     17  Cedevita Olimpija Ljubljana
# 4             4  2024-01-31T18:00:00     17          Turk Telekom Ankara
# ..          ...                  ...    ...                          ...
# 168         165  2023-10-04T18:00:00      1             U-BT Cluj-Napoca
# 169         166  2023-10-04T18:00:00      1        Prometey Slobozhanske
# 170         167  2023-10-03T20:30:00      1             Paris Basketball
# 171         168  2023-10-03T19:30:00      1               ratiopharm Ulm
# 172         169  2023-10-03T19:00:00      1       Hapoel Shlomo Tel Aviv
#
#                           visitante  localscore  roadscore    Ganador  \
# 0                  U-BT Cluj-Napoca         111      113.0  Visitante
# 1          Buducnost VOLI Podgorica          78       97.0  Visitante
# 2           Aris Midea Thessaloniki          66       86.0  Visitante
# 3                      London Lions          85       92.0  Visitante
# 4    Mincidelice JL Bourg en Bresse          64       68.0  Visitante
# ..                              ...         ...        ...        ...
# 168             Turk Telekom Ankara          80       71.0      Local
# 169           Veolia Towers Hamburg          97       77.0      Local
# 170                  Wolves Vilnius         105       78.0      Local
# 171         Dolomiti Energia Trento          80       70.0      Local
# 172     Cedevita Olimpija Ljubljana         100       73.0      Local
#
#      plusminus Competition
# 0         -2.0     Eurocup
# 1        -19.0     Eurocup
# 2        -20.0     Eurocup
# 3         -7.0     Eurocup
# 4         -4.0     Eurocup
# ..         ...         ...
# 168        9.0     Eurocup
# 169       20.0     Eurocup
# 170       27.0     Eurocup
# 171       10.0     Eurocup
# 172       27.0     Eurocup
#
# [170 rows x 10 columns]

# %% [markdown]
# As seen in the first look at the dataframes, there was a problem with the columns: Are lower when they should be Capitalized, as in the Euroleague DataFrame. Change the column names to capitalize.
#
# is there a quick way to do it?

# %%
cup.columns = cup.columns.str.capitalize()
cup
# Out:
#      Unnamed: 0                Fecha  Ronda                        Local  \
# 0             0  2024-01-31T21:00:00     17       Dreamland Gran Canaria
# 1             1  2024-01-31T20:00:00     17      Dolomiti Energia Trento
# 2             2  2024-01-31T19:30:00     17               ratiopharm Ulm
# 3             3  2024-01-31T18:30:00     17  Cedevita Olimpija Ljubljana
# 4             4  2024-01-31T18:00:00     17          Turk Telekom Ankara
# ..          ...                  ...    ...                          ...
# 168         165  2023-10-04T18:00:00      1             U-BT Cluj-Napoca
# 169         166  2023-10-04T18:00:00      1        Prometey Slobozhanske
# 170         167  2023-10-03T20:30:00      1             Paris Basketball
# 171         168  2023-10-03T19:30:00      1               ratiopharm Ulm
# 172         169  2023-10-03T19:00:00      1       Hapoel Shlomo Tel Aviv
#
#                           Visitante  Localscore  Roadscore    Ganador  \
# 0                  U-BT Cluj-Napoca         111      113.0  Visitante
# 1          Buducnost VOLI Podgorica          78       97.0  Visitante
# 2           Aris Midea Thessaloniki          66       86.0  Visitante
# 3                      London Lions          85       92.0  Visitante
# 4    Mincidelice JL Bourg en Bresse          64       68.0  Visitante
# ..                              ...         ...        ...        ...
# 168             Turk Telekom Ankara          80       71.0      Local
# 169           Veolia Towers Hamburg          97       77.0      Local
# 170                  Wolves Vilnius         105       78.0      Local
# 171         Dolomiti Energia Trento          80       70.0      Local
# 172     Cedevita Olimpija Ljubljana         100       73.0      Local
#
#      Plusminus Competition
# 0         -2.0     Eurocup
# 1        -19.0     Eurocup
# 2        -20.0     Eurocup
# 3         -7.0     Eurocup
# 4         -4.0     Eurocup
# ..         ...         ...
# 168        9.0     Eurocup
# 169       20.0     Eurocup
# 170       27.0     Eurocup
# 171       10.0     Eurocup
# 172       27.0     Eurocup
#
# [170 rows x 10 columns]

# %% [markdown]
# Now it is time to just take the useful columns from each data! We will call the result subsets `comp_el` and `comp_ec`
#
# REMEMBER: Use the same order of the columns for each dataset.
#
# Recommended order: Competition, Localscore, Roadscore, Plusminus, Ganador. **Nothing else is useful**

# %%
comp_el = league[['Competition', 'Localscore', 'Roadscore', 'Plusminus', 'Ganador']]
comp_ec = cup[['Competition', 'Localscore', 'Roadscore', 'Plusminus', 'Ganador']]

# %%
comp_el
# Out:
#     Competition  Localscore  Roadscore  Plusminus    Ganador
# 0    Euroleague          94         73         21      Local
# 1    Euroleague          96         81         15      Local
# 2    Euroleague          79         82         -3  Visitante
# 3    Euroleague          80         68         12      Local
# 4    Euroleague          91         74         17      Local
# ..          ...         ...        ...        ...        ...
# 220  Euroleague          79         73          6      Local
# 221  Euroleague          80         68         12      Local
# 222  Euroleague          76         85         -9  Visitante
# 223  Euroleague          88         84          4      Local
# 224  Euroleague          76         69          7      Local
#
# [225 rows x 5 columns]

# %%
comp_ec
# Out:
#     Competition  Localscore  Roadscore  Plusminus    Ganador
# 0       Eurocup         111      113.0       -2.0  Visitante
# 1       Eurocup          78       97.0      -19.0  Visitante
# 2       Eurocup          66       86.0      -20.0  Visitante
# 3       Eurocup          85       92.0       -7.0  Visitante
# 4       Eurocup          64       68.0       -4.0  Visitante
# ..          ...         ...        ...        ...        ...
# 168     Eurocup          80       71.0        9.0      Local
# 169     Eurocup          97       77.0       20.0      Local
# 170     Eurocup         105       78.0       27.0      Local
# 171     Eurocup          80       70.0       10.0      Local
# 172     Eurocup         100       73.0       27.0      Local
#
# [170 rows x 5 columns]

# %% [markdown]
# Time to concatenate them both! Create a concat of both Dfs, called `competition`

# %%
competition = pd.concat([comp_el, comp_ec])
competition
# Out:
#     Competition  Localscore  Roadscore  Plusminus    Ganador
# 0    Euroleague          94       73.0       21.0      Local
# 1    Euroleague          96       81.0       15.0      Local
# 2    Euroleague          79       82.0       -3.0  Visitante
# 3    Euroleague          80       68.0       12.0      Local
# 4    Euroleague          91       74.0       17.0      Local
# ..          ...         ...        ...        ...        ...
# 168     Eurocup          80       71.0        9.0      Local
# 169     Eurocup          97       77.0       20.0      Local
# 170     Eurocup         105       78.0       27.0      Local
# 171     Eurocup          80       70.0       10.0      Local
# 172     Eurocup         100       73.0       27.0      Local
#
# [395 rows x 5 columns]

# %% [markdown]
# ## Well done!
#
# Now we have the combination of both competitions in the same dataframe. Is time for the questions you must answer:

# %% [markdown]
# 1. How many matches have been in each competition?
# 2. What are the maximum points that a local team has scored per competition? And the road team as well.
# 3. Do the same operations with the average points (per competition)
# 4. Can you tell me the maximum difference that has been in a match, splitted by competition?
#     - Careful: The Plusminus is both positive and negative, being negative that the Road Team has achieved the Victory. To have the absolute, create a new Column named Absolut_Plusminus. Remember: np.where is life!
# 5. Also grouped by competition, give me the number of victories of the Locals and the Visitors

# %%
# 1
partidos_por_comp = competition['Competition'].value_counts()
print("Número de partidos por competición:")
print(partidos_por_comp)
# Out:
# Número de partidos por competición:
# Competition
# Euroleague    225
# Eurocup       170
# Name: count, dtype: int64

# %%
# 2
max_local_por_comp = competition.groupby('Competition')['Localscore'].max()
max_visitante_por_comp = competition.groupby('Competition')['Roadscore'].max()
print("Máximo de puntos conseguido por equipo local por competición:")
print(max_local_por_comp)
print("\nMáximo de puntos conseguido por equipo visitante por competición:")
print(max_visitante_por_comp)
# Out:
# Máximo de puntos conseguido por equipo local por competición:
# Competition
# Eurocup       120
# Euroleague    130
# Name: Localscore, dtype: int64
#
# Máximo de puntos conseguido por equipo visitante por competición:
# Competition
# Eurocup       114.0
# Euroleague    126.0
# Name: Roadscore, dtype: float64

# %%
# 3
media_puntos_por_comp = competition.groupby('Competition')[['Localscore', 'Roadscore']].mean()
print("Media de puntos por competición:")
print(media_puntos_por_comp)
# Out:
# Media de puntos por competición:
#              Localscore  Roadscore
# Competition
# Eurocup       85.235294  83.958824
# Euroleague    83.284444  79.173333

# %%
# 4
competition['Absolut_Plusminus'] = competition['Plusminus'].abs()
max_diferencia_por_comp = competition.groupby('Competition')['Absolut_Plusminus'].max()
print("Diferencia máxima de puntos por partido dividida por competición:")
print(max_diferencia_por_comp)
# Out:
# Diferencia máxima de puntos por partido dividida por competición:
# Competition
# Eurocup       39.0
# Euroleague    39.0
# Name: Absolut_Plusminus, dtype: float64

# %%
# 5
victorias_locales = competition[competition['Ganador'] == 'Local'].groupby('Competition').size()
victorias_visitantes = competition[competition['Ganador'] == 'Visitante'].groupby('Competition').size()
print("Número de victorias de los locales por competición:")
print(victorias_locales)
print("Número de victorias de los visitantes por competición:")
print(victorias_visitantes)
# Out:
# Número de victorias de los locales por competición:
# Competition
# Eurocup        90
# Euroleague    150
# dtype: int64
# Número de victorias de los visitantes por competición:
# Competition
# Eurocup       80
# Euroleague    75
# dtype: int64
